# %%
import numpy as np
import pandas as pd

# %%
np.__version__
# Out:
# '1.19.5'

# %%
pd.__version__
# Out:
# '1.3.2'

# %%
car_price_df = pd.read_csv('./car_price_data.csv')

# %%
car_price_df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
car_price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
bmw_df = car_price_df[car_price_df['Make'] == 'BMW']
print(bmw_df.MSRP.mean())
# Out:
# 61546.76347305389

# %% [markdown]
# Therefore, the average price of BMW cars in the dataset is : **61546**.

# %%
car_price_df[car_price_df.Year >= 2015]
# Out:
#        Make       Model  Year                Engine Fuel Type  Engine HP  \
# 32     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 33     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 34     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 41      BMW    2 Series  2016     premium unleaded (required)      240.0
# 42      BMW    2 Series  2016     premium unleaded (required)      240.0
# ...     ...         ...   ...                             ...        ...
# 11898   BMW          Z4  2015     premium unleaded (required)      300.0
# 11899   BMW          Z4  2015     premium unleaded (required)      335.0
# 11900   BMW          Z4  2016     premium unleaded (required)      300.0
# 11901   BMW          Z4  2016     premium unleaded (required)      240.0
# 11902   BMW          Z4  2016     premium unleaded (required)      335.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %%
car_price_df[car_price_df.Year >= 2015].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5995 entries, 32 to 11902
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               5995 non-null   object
#  1   Model              5995 non-null   object
#  2   Year               5995 non-null   int64
#  3   Engine Fuel Type   5995 non-null   object
#  4   Engine HP          5944 non-null   float64
#  5   Engine Cylinders   5987 non-null   float64
#  6   Transmission Type  5995 non-null   object
#  7   Driven_Wheels      5995 non-null   object
#  8   Number of Doors    5990 non-null   float64
#  9   Market Category    4671 non-null   object
#  10  Vehicle Size       5995 non-null   object
#  11  Vehicle Style      5995 non-null   object
#  12  highway MPG        5995 non-null   int64
#  13  city mpg           5995 non-null   int64
#  14  Popularity         5995 non-null   int64
#  15  MSRP               5995 non-null   int64
# ...

# %% [markdown]
# We have a total of 5995 entries with year >= 2015. And using the df.info() method we find that there are 5944 non-null values in the Engine HP column. Therefore number of missing values for Engine HP = 5995 - 5944

# %%
car_price_df[(car_price_df.Year >= 2015)]['Engine HP'].isnull().sum()
# Out:
# 51

# %% [markdown]
# Therefore, number of missing values for Engine HP after the year 2015 = **51**.

# %%
car_price_df.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
mean_hp_before = car_price_df['Engine HP'].mean()
print(round(mean_hp_before))
values = {'Engine HP': mean_hp_before}
# Out:
# 249

# %%
updated_car_price_df = car_price_df.fillna(value=values)
updated_car_price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11914 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
mean_hp_after = updated_car_price_df['Engine HP'].mean()
print(round(mean_hp_after))
# Out:
# 249

# %% [markdown]
# Therefore, there is **NO change in the mean value**.

# %%
rolls_royce_df = car_price_df[car_price_df['Make'] == 'Rolls-Royce'][["Engine HP", "Engine Cylinders", "highway MPG"]]
unique_rows = rolls_royce_df.drop_duplicates()
print(unique_rows)
# Out:
#        Engine HP  Engine Cylinders  highway MPG
# 2921       325.0               8.0           15
# 3505       563.0              12.0           19
# 5275       563.0              12.0           21
# 5279       563.0              12.0           20
# 7443       322.0              12.0           15
# 7553       453.0              12.0           19
# 11448      624.0              12.0           21

# %%
X = np.array(unique_rows)
print(X)
# Out:
# [[325.   8.  15.]
#  [563.  12.  19.]
#  [563.  12.  21.]
#  [563.  12.  20.]
#  [322.  12.  15.]
#  [453.  12.  19.]
#  [624.  12.  21.]]

# %%
er = np.array([
    [1,2,3],
    [4,5,6],
    [5,6,7]
])
#np.linalg.inv(er)

# %%
XTX = X.T @ X
np.linalg.inv(XTX).sum()
# Out:
# 0.032212320677486125

# %% [markdown]
# Therefore, the sum of all the elements of the result is : **0.0322**.

# %%
y = np.array([1000, 1100, 900, 1200, 1000, 850, 1300])

# %%
w = (np.linalg.inv(XTX) @ X.T) @ y
print(w)
# Out:
# [ 0.19989598 31.02612262 31.65378877]

# %% [markdown]
# Therefore, the first element of w is **0.1998**.
